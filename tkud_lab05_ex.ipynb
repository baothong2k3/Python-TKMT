# %% [markdown]
# # Bài Tập

# %%
# %matplotlib inline
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### Bài 1: Tạo quần thể mô phỏng
#
# Bạn hãy tạo một mẫu gồm 10000 phần tử mô phỏng chiều cao của nam thanh niên có giá trị từ 120cm - 200cm. Bạn hãy lưu kết quả vào biến **POP**.
#
# Tính:
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
#
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
#
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
#
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.

# %%
pop = np.random.randint(120, 201, 1000)
pop
# Out:
# array([139, 189, 143, 133, 180, 138, 176, 126, 165, 153, 162, 120, 196,
#        150, 126, 143, 145, 199, 159, 197, 186, 124, 137, 125, 153, 124,
#        150, 156, 147, 200, 164, 188, 178, 160, 156, 179, 154, 184, 181,
#        175, 177, 136, 143, 188, 173, 166, 153, 196, 140, 187, 129, 140,
#        177, 180, 139, 125, 124, 176, 160, 198, 168, 127, 156, 133, 175,
#        182, 153, 133, 163, 121, 161, 170, 184, 181, 171, 167, 164, 149,
#        194, 187, 126, 189, 127, 128, 190, 170, 176, 129, 168, 167, 131,
#        188, 149, 189, 166, 168, 179, 168, 193, 131, 194, 143, 185, 184,
#        176, 192, 121, 189, 121, 192, 187, 169, 194, 179, 157, 194, 172,
#        146, 131, 149, 191, 158, 173, 192, 146, 140, 174, 170, 179, 144,
#        152, 122, 158, 174, 181, 185, 196, 171, 150, 150, 181, 140, 146,
#        197, 191, 150, 156, 123, 141, 190, 150, 196, 199, 148, 197, 183,
#        158, 170, 141, 138, 176, 131, 133, 162, 167, 140, 121, 173, 154,
#        169, 120, 135, 196, 199, 193, 180, 152, 134, 131, 166, 149, 172,
#        189, 183, 152, 171, 155, 182, 198, 143, 137, 178, 122, 183, 126,
#        157, 159, 147, 126, 141, 171, 166, 176, 164, 193, 152, 162, 152,
#        176, 196, 154, 179, 137, 128, 148, 191, 162, 129, 123, 164, 166,
#        193, 144, 178, 179, 125, 197, 132, 171, 170, 144, 195, 199, 152,
#        120, 124, 184, 138, 192, 165, 123, 164, 157, 127, 196, 190, 129,
#        191, 150, 148, 164, 168, 137, 150, 166, 140, 180, 157, 177, 121,
#        187, 181, 193, 131, 138, 180, 146, 181, 162, 134, 169, 176, 199,
#        160, 192, 132, 159, 130, 156, 171, 140, 193, 149, 158, 154, 146,
#        191, 133, 198, 175, 167, 183, 154, 123, 171, 150, 154, 167, 168,
#        179, 190, 193, 172, 166, 196, 146, 193, 127, 172, 200, 140, 177,
#        172, 139, 190, 140, 199, 198, 182, 162, 169, 143, 179, 152, 196,
#        162, 197, 200, 131, 195, 168, 184, 196, 132, 160, 145, 125, 127,
#        161, 136, 151, 125, 170, 139, 124, 186, 153, 154, 166, 187, 154,
#        198, 150, 160, 185, 179, 175, 181, 120, 136, 143, 161, 188, 161,
#        157, 175, 160, 188, 133, 183, 159, 136, 154, 132, 165, 140, 130,
#        153, 160, 179, 183, 135, 182, 125, 162, 161, 146, 178, 135, 168,
#        125, 123, 133, 159, 165, 190, 129, 169, 181, 133, 151, 179, 162,
#        126, 147, 144, 125, 139, 120, 173, 145, 134, 181, 179, 130, 149,
#        171, 152, 181, 174, 161, 151, 135, 197, 136, 199, 174, 126, 199,
#        179, 179, 199, 181, 136, 148, 171, 187, 125, 151, 171, 135, 170,
#        129, 163, 129, 142, 120, 177, 173, 159, 183, 194, 133, 198, 188,
#        156, 144, 121, 185, 168, 139, 175, 140, 125, 146, 147, 173, 130,
#        148, 162, 126, 179, 133, 183, 154, 163, 159, 175, 142, 151, 130,
#        130, 162, 124, 140, 181, 130, 165, 133, 142, 155, 172, 136, 147,
#        186, 194, 132, 182, 142, 134, 174, 155, 163, 172, 177, 170, 191,
#        148, 196, 197, 199, 166, 200, 179, 130, 157, 191, 152, 134, 172,
#        178, 140, 160, 122, 147, 177, 153, 144, 142, 130, 123, 171, 155,
#        137, 134, 199, 183, 168, 127, 174, 175, 187, 184, 128, 183, 156,
#        190, 190, 120, 197, 123, 191, 199, 153, 200, 131, 185, 175, 191,
#        127, 136, 183, 182, 175, 163, 131, 124, 169, 141, 174, 174, 183,
#        183, 147, 153, 174, 136, 120, 177, 171, 169, 126, 170, 123, 129,
#        153, 177, 156, 172, 129, 190, 150, 139, 167, 153, 160, 160, 190,
#        197, 193, 146, 174, 144, 163, 130, 138, 167, 196, 139, 130, 128,
#        174, 159, 170, 156, 200, 179, 123, 180, 154, 136, 122, 142, 153,
#        179, 139, 157, 144, 134, 135, 123, 166, 132, 166, 160, 182, 176,
#        197, 170, 150, 167, 125, 136, 154, 120, 192, 131, 136, 170, 176,
#        153, 152, 156, 158, 135, 152, 179, 181, 156, 141, 126, 193, 198,
#        179, 131, 176, 135, 184, 194, 165, 172, 131, 198, 137, 167, 195,
#        188, 194, 185, 160, 143, 196, 131, 198, 176, 124, 169, 187, 161,
#        126, 169, 154, 133, 169, 152, 160, 177, 160, 134, 170, 143, 197,
#        179, 180, 194, 135, 170, 129, 158, 182, 190, 135, 128, 196, 167,
#        184, 168, 157, 183, 191, 146, 175, 149, 147, 172, 166, 158, 140,
#        192, 170, 189, 128, 130, 152, 197, 120, 160, 154, 168, 155, 165,
#        186, 140, 121, 159, 191, 165, 158, 187, 151, 190, 163, 129, 179,
#        187, 127, 156, 158, 161, 128, 148, 141, 159, 189, 178, 156, 140,
#        163, 152, 161, 186, 173, 165, 182, 192, 176, 136, 124, 176, 195,
#        170, 131, 183, 173, 124, 197, 152, 165, 178, 121, 148, 151, 135,
#        180, 171, 169, 153, 145, 179, 161, 188, 132, 177, 141, 154, 148,
#        162, 155, 185, 164, 193, 160, 142, 127, 172, 178, 177, 158, 142,
#        184, 169, 161, 159, 150, 193, 147, 160, 158, 123, 190, 178, 198,
#        137, 170, 191, 153, 144, 147, 159, 124, 140, 175, 143, 171, 175,
#        120, 200, 120, 200, 156, 171, 181, 160, 157, 126, 194, 159, 128,
#        163, 168, 179, 178, 130, 160, 144, 182, 138, 129, 188, 150, 128,
#        163, 200, 129, 179, 169, 128, 176, 173, 144, 183, 124, 153, 150,
#        143, 153, 186, 169, 191, 165, 192, 131, 139, 175, 185, 130, 146,
#        143, 182, 157, 136, 133, 126, 131, 172, 129, 179, 172, 161, 194,
#        161, 160, 169, 123, 171, 142, 180, 199, 171, 156, 136, 162, 163,
#        121, 187, 194, 145, 182, 121, 164, 191, 157, 158, 141, 162, 125,
#        199, 147, 130, 151, 156, 199, 161, 189, 134, 147, 121, 198, 134,
#        142, 130, 120, 175, 145, 130, 159, 171, 190, 147, 160, 176, 199,
#        153, 196, 200, 134, 148, 172, 152, 195, 162, 128, 139, 143, 190,
#        189, 171, 160, 178, 154, 120, 186, 152, 173, 198, 153, 196, 122,
#        190, 182, 154, 124, 134, 133, 182, 197, 141, 180, 151, 134])

# %%
mean_pop = np.mean(pop)
print('Chiều cao trung bình của Quần Thể : {}'.format(mean_pop))
pop_tall = pop[pop>180]
print('Tỉ lệ người cao: {}'.format(pop_tall.size/pop.size))
# Out:
# Chiều cao trung bình của Quần Thể : 160.552
# Tỉ lệ người cao: 0.233

# %%
plt.hist(pop, bins= 100)
plt.show()

# %%
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import t

# %%
dolechchuan = np.std(pop)
print('Độ lệch chuẩn của quần thể: {}'.format(dolechchuan))
# Vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.
norm_10k = norm.rvs(size=10000, loc=mean_pop, scale=dolechchuan)
plt.hist(norm_10k, bins=50, density=True)
plt.show()
# Out:
# Độ lệch chuẩn của quần thể: 22.916659791514117

# %% [markdown]
# ### Bài 2: Lấy mẫu cỡ 20
#
# Bạn hãy lấy một mẫu kích thước 20 phần từ. Tính:
#
# a. Trung bình mẫu, và độ lệch chuẩn của mẫu
#
# b. Tỷ lệ người cao của mẫu
#
# c. Vẽ histogram của mẫu
#
# d. Thử vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu. Bạn có nhận xét gì không?

# %%
sample = np.random.choice(pop, 20)
sample
# a. Tính giá trị trung bình và độ lệch chuẩn
mean = sample.mean()
std_dev = sample.std()
print(f"Mean: {mean}, Standard Deviation: {std_dev}")

# b. Tính tỷ lệ người cao
tall = 180
tall_proportion = (sample >= tall).mean()
print(f"Proportion of tall people: {tall_proportion}")

# c. Plot histogram
plt.hist(sample, bins='auto')
plt.title("Histogram of Heights")
plt.show()

# d. Vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu.
x = np.linspace(mean - 3*std_dev, mean + 3*std_dev, 100)
plt.plot(x, norm.pdf(x, mean, std_dev))
plt.title("Normal Distribution of Heights")
plt.show()
# Out:
# Mean: 169.8, Standard Deviation: 26.131590077911444
# Proportion of tall people: 0.4

# %% [markdown]
# ### Bài 3: Lấy mẫu cỡ 100
#
# Lặp lại thí nghiệm bài 2 với cỡ mẫu là 100

# %%
sample = np.random.choice(pop, 100)
sample
# a. Tính giá trị trung bình và độ lệch chuẩn
mean = sample.mean()
std_dev = sample.std()
print(f"Mean: {mean}, Standard Deviation: {std_dev}")

# b. Tính tỷ lệ người cao
tall = 180
tall_proportion = (sample >= tall).mean()
print(f"Proportion of tall people: {tall_proportion}")

# c. Plot histogram
plt.hist(sample, bins='auto')
plt.title("Histogram of Heights")
plt.show()

# d. Vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu.
x = np.linspace(mean - 3*std_dev, mean + 3*std_dev, 100)
plt.plot(x, norm.pdf(x, mean, std_dev))
plt.title("Normal Distribution of Heights")
plt.show()
# Out:
# Mean: 162.01, Standard Deviation: 23.792223519461146
# Proportion of tall people: 0.26

# %% [markdown]
# ### Bài 4: Khảo sát phân phối của trung bình mẫu
#
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
#
# Gợi ý: tạo một danh sách rỗng để chứa các trung bình mẫu tính được, sử dụng hàm append() để thêm giá trị trung bình vào danh sách sau mỗi lần tính.

# %% [markdown]
# ### Bài 5: Khảo sát tỷ lệ mẫu
#
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
#
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu

# %% [markdown]
# ### Bài 6: Khảo sát phương sai mẫu
#
# Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram đại lượng phương sai của các mẫu (Phương sai bằng bình phương độ lệch chuẩn)

# %% [markdown]
# ### Bài 7:  Bài Tập Ước Lượng
#
# Khảo sát cân nặng (kg) của gà khi xuất chuồng, người ta cân một số con và có kết quả như sau:
#
# > 2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8
#
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của  khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
#
# a, Biết $\sigma = 0.3$
#
# b, Không biết $\sigma$
